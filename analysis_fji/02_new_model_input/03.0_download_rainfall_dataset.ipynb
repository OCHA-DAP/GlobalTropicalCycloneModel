# %% [markdown]
# # Notebook that downloads GPM rainfall data done per typhoon

# %%
# %load_ext jupyter_black
# Out:
#                 <script type="application/javascript" id="jupyter_black">
#                 (function() {
#                     if (window.IPython === undefined) {
#                         return
#                     }
#                     var msg = "WARNING: it looks like you might have loaded " +
#                         "jupyter_black in a non-lab notebook with " +
#                         "`is_lab=True`. Please double check, and if " +
#                         "loading with `%load_ext` please review the README!"
#                     console.log(msg)
#                     alert(msg)
#                 })()
#                 </script>

# %%
import getpass
import os
from pathlib import Path


import pandas as pd
import datetime as dt
from bs4 import BeautifulSoup
import requests

from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
# Setting directories
input_dir = (
    Path(os.getenv("STORM_DATA_DIR"))
    / "analysis/02_new_model_input_fji/03_rainfall/input"
)
# Setting path to save the GPM data
gpm_file_name = "gpm_data/rainfall_data/output_hhr/"
gpm_folder_path = Path(input_dir, gpm_file_name)

# %%
# To create an account for downloading the data
# follow the instructions here: https://registration.pps.eosdis.nasa.gov/registration/
# Change the user name and provide the password in the code
USERNAME = getpass.getpass(prompt="Username: ", stream=None)
PASSWORD = getpass.getpass(prompt="Password: ", stream=None)

# Setting the number of days prior to the landfall data for which to collect data
DAYS_TO_LANDFALL = 2
# Out:
# Username:  ········
# Password:  ········

# %%
# Load and clean the typhoon metadata
# We really only care about the landfall date
typhoon_metadata = pd.read_csv(input_dir / "metadata_typhoons.csv").set_index(
    "typhoon"
)
for colname in ["startdate", "enddate", "landfalldate"]:
    typhoon_metadata[colname] = pd.to_datetime(
        typhoon_metadata[colname], format="%d/%m/%Y"
    )
typhoon_metadata
# Out:
#               startdate    enddate landfalldate landfall_time
# typhoon
# bebe1972     1972-10-19 1972-10-26   1972-10-22      20:30:00
# bebe1972     1972-10-27 1972-10-28   1972-10-27      00:00:00
# juliette1973 1973-04-03 1973-04-04   1973-04-03      12:30:00
# juliette1973 1973-04-02 1973-04-03   1973-04-03      00:00:00
# juliette1973 1973-04-05 1973-04-06   1973-04-05      00:00:00
# ...                 ...        ...          ...           ...
# tino2020     2020-01-16 2020-01-19   2020-01-17      05:30:00
# harold2020   2020-04-01 2020-04-10   2020-04-08      00:30:00
# yasa2020     2020-12-13 2020-12-20   2020-12-17      06:00:00
# bina2021     2021-01-31 2021-01-31   2021-01-31      13:30:00
# ana2021      2021-01-29 2021-02-01   2021-01-30      10:00:00
#
# [77 rows x 4 columns]

# %%
# %% Functions used
def list_files(url):
    response = requests.get(url, auth=(USERNAME, PASSWORD))
    if response.status_code == 404:
        print(f"{url} not available")
        return []
    page = response.text
    soup = BeautifulSoup(page, "html.parser")
    return [
        url + "/" + node.get("href")
        for node in soup.find_all("a")
        if node.get("href").endswith("tif")
    ]


def download_gpm_http(start_date, end_date, download_path):
    base_url = "https://arthurhouhttps.pps.eosdis.nasa.gov/pub/gpmdata"

    date_list = pd.date_range(start_date, end_date)
    file_list = []

    for date in date_list:
        print(f"Downloading data for date {date}")
        day_path = download_path / date.strftime("%Y%m%d")
        day_path.mkdir(parents=True, exist_ok=True)

        url = f"{base_url}/{date.strftime('%Y/%m/%d')}/gis"
        tiff_files = list_files(url=url)

        for tiff_file in tiff_files:
            file_name = tiff_file.split("/")[-1]

            file_path = day_path / file_name
            # don't download if file already exists
            if file_path.exists():
                print(f"{file_path} already exists")
                continue
            file_list.append(file_path)
            r = requests.get(tiff_file, auth=(user_name, user_name))
            print(r)
            open(file_path, "wb").write(r.content)

    return file_list

# %% [markdown]
# ## Download the data
#
# This section is for downloading the data.
# It takes a long time to complete.

# %%
for typhoon, metadata in typhoon_metadata.iterrows():
    start_date = metadata["landfalldate"] - dt.timedelta(days=DAYS_TO_LANDFALL)
    end_date = metadata["landfalldate"] + dt.timedelta(days=DAYS_TO_LANDFALL)
    if start_date.year < 1987:
        print("too early, skipping")
        continue
    print(f"Downloading data for {typhoon} between {start_date} and {end_date}") 
    download_gpm_http(start_date=start_date, 
                      end_date=end_date, 
                      download_path=gpm_folder_path / typhoon / "GPM")
# Out:
# too early, skipping
# too early, skipping
# too early, skipping
# too early, skipping
# too early, skipping
# too early, skipping
# too early, skipping
# too early, skipping
# too early, skipping
# too early, skipping
# too early, skipping
# too early, skipping
# too early, skipping
# too early, skipping
# too early, skipping
# too early, skipping
# too early, skipping
# too early, skipping
# too early, skipping
# too early, skipping
# too early, skipping
# too early, skipping
# too early, skipping
# too early, skipping
# too early, skipping
# too early, skipping
# too early, skipping
# Downloading data for tusi1987 between 1987-01-16 00:00:00 and 1987-01-20 00:00:00
# Downloading data for date 1987-01-16 00:00:00
# https://arthurhouhttps.pps.eosdis.nasa.gov/pub/gpmdata/1987/01/16/gis not available
# Downloading data for date 1987-01-17 00:00:00
# https://arthurhouhttps.pps.eosdis.nasa.gov/pub/gpmdata/1987/01/17/gis not available
# Downloading data for date 1987-01-18 00:00:00
# https://arthurhouhttps.pps.eosdis.nasa.gov/pub/gpmdata/1987/01/18/gis not available
# Downloading data for date 1987-01-19 00:00:00
# https://arthurhouhttps.pps.eosdis.nasa.gov/pub/gpmdata/1987/01/19/gis not available
# Downloading data for date 1987-01-20 00:00:00
# https://arthurhouhttps.pps.eosdis.nasa.gov/pub/gpmdata/1987/01/20/gis not available
# Downloading data for bola1988 between 1988-02-23 00:00:00 and 1988-02-27 00:00:00
# Downloading data for date 1988-02-23 00:00:00
# https://arthurhouhttps.pps.eosdis.nasa.gov/pub/gpmdata/1988/02/23/gis not available
# Downloading data for date 1988-02-24 00:00:00
# https://arthurhouhttps.pps.eosdis.nasa.gov/pub/gpmdata/1988/02/24/gis not available
# Downloading data for date 1988-02-25 00:00:00
# https://arthurhouhttps.pps.eosdis.nasa.gov/pub/gpmdata/1988/02/25/gis not available
# Downloading data for date 1988-02-26 00:00:00
# https://arthurhouhttps.pps.eosdis.nasa.gov/pub/gpmdata/1988/02/26/gis not available
# Downloading data for date 1988-02-27 00:00:00
# https://arthurhouhttps.pps.eosdis.nasa.gov/pub/gpmdata/1988/02/27/gis not available
# Downloading data for eseta1988 between 1988-12-22 00:00:00 and 1988-12-26 00:00:00
# Downloading data for date 1988-12-22 00:00:00
# https://arthurhouhttps.pps.eosdis.nasa.gov/pub/gpmdata/1988/12/22/gis not available
# Downloading data for date 1988-12-23 00:00:00
# https://arthurhouhttps.pps.eosdis.nasa.gov/pub/gpmdata/1988/12/23/gis not available
# Downloading data for date 1988-12-24 00:00:00
# https://arthurhouhttps.pps.eosdis.nasa.gov/pub/gpmdata/1988/12/24/gis not available
# Downloading data for date 1988-12-25 00:00:00
# https://arthurhouhttps.pps.eosdis.nasa.gov/pub/gpmdata/1988/12/25/gis not available
# Downloading data for date 1988-12-26 00:00:00
# https://arthurhouhttps.pps.eosdis.nasa.gov/pub/gpmdata/1988/12/26/gis not available
# Downloading data for harry1989 between 1989-02-08 00:00:00 and 1989-02-12 00:00:00
# Downloading data for date 1989-02-08 00:00:00
# https://arthurhouhttps.pps.eosdis.nasa.gov/pub/gpmdata/1989/02/08/gis not available
# Downloading data for date 1989-02-09 00:00:00
# https://arthurhouhttps.pps.eosdis.nasa.gov/pub/gpmdata/1989/02/09/gis not available
# Downloading data for date 1989-02-10 00:00:00
# https://arthurhouhttps.pps.eosdis.nasa.gov/pub/gpmdata/1989/02/10/gis not available
# Downloading data for date 1989-02-11 00:00:00
# https://arthurhouhttps.pps.eosdis.nasa.gov/pub/gpmdata/1989/02/11/gis not available
# Downloading data for date 1989-02-12 00:00:00
# https://arthurhouhttps.pps.eosdis.nasa.gov/pub/gpmdata/1989/02/12/gis not available
# Downloading data for kerry1989 between 1989-03-28 00:00:00 and 1989-04-01 00:00:00
# Downloading data for date 1989-03-28 00:00:00
# https://arthurhouhttps.pps.eosdis.nasa.gov/pub/gpmdata/1989/03/28/gis not available
# Downloading data for date 1989-03-29 00:00:00
# https://arthurhouhttps.pps.eosdis.nasa.gov/pub/gpmdata/1989/03/29/gis not available
# Downloading data for date 1989-03-30 00:00:00
# https://arthurhouhttps.pps.eosdis.nasa.gov/pub/gpmdata/1989/03/30/gis not available
# Downloading data for date 1989-03-31 00:00:00
# https://arthurhouhttps.pps.eosdis.nasa.gov/pub/gpmdata/1989/03/31/gis not available
# Downloading data for date 1989-04-01 00:00:00
# https://arthurhouhttps.pps.eosdis.nasa.gov/pub/gpmdata/1989/04/01/gis not available
# Downloading data for rae1990 between 1990-03-17 00:00:00 and 1990-03-21 00:00:00
# Downloading data for date 1990-03-17 00:00:00
# https://arthurhouhttps.pps.eosdis.nasa.gov/pub/gpmdata/1990/03/17/gis not available
# Downloading data for date 1990-03-18 00:00:00
# https://arthurhouhttps.pps.eosdis.nasa.gov/pub/gpmdata/1990/03/18/gis not available
# Downloading data for date 1990-03-19 00:00:00
# https://arthurhouhttps.pps.eosdis.nasa.gov/pub/gpmdata/1990/03/19/gis not available
# Downloading data for date 1990-03-20 00:00:00
# https://arthurhouhttps.pps.eosdis.nasa.gov/pub/gpmdata/1990/03/20/gis not available
# Downloading data for date 1990-03-21 00:00:00
# https://arthurhouhttps.pps.eosdis.nasa.gov/pub/gpmdata/1990/03/21/gis not available
# Downloading data for rae1990 between 1990-03-21 00:00:00 and 1990-03-25 00:00:00
# Downloading data for date 1990-03-21 00:00:00
# https://arthurhouhttps.pps.eosdis.nasa.gov/pub/gpmdata/1990/03/21/gis not available
# Downloading data for date 1990-03-22 00:00:00
# https://arthurhouhttps.pps.eosdis.nasa.gov/pub/gpmdata/1990
00:00:00
# https://arthurhouhttps.pps.eosdis.nasa.gov/pub/gpmdata/1997/03/08/gis not available
# Downloading data for date 1997-03-09 00:00:00
# https://arthurhouhttps.pps.eosdis.nasa.gov/pub/gpmdata/1997/03/09/gis not available
# Downloading data for ian1997 between 1997-04-16 00:00:00 and 1997-04-20 00:00:00
# Downloading data for date 1997-04-16 00:00:00
# https://arthurhouhttps.pps.eosdis.nasa.gov/pub/gpmdata/1997/04/16/gis not available
# Downloading data for date 1997-04-17 00:00:00
# https://arthurhouhttps.pps.eosdis.nasa.gov/pub/gpmdata/1997/04/17/gis not available
# Downloading data for date 1997-04-18 00:00:00
# https://arthurhouhttps.pps.eosdis.nasa.gov/pub/gpmdata/1997/04/18/gis not available
# Downloading data for date 1997-04-19 00:00:00
# https://arthurhouhttps.pps.eosdis.nasa.gov/pub/gpmdata/1997/04/19/gis not available
# Downloading data for date 1997-04-20 00:00:00
# https://arthurhouhttps.pps.eosdis.nasa.gov/pub/gpmdata/1997/04/20/gis not available
# Downloading data for june1997 between 1997-05-03 00:00:00 and 1997-05-07 00:00:00
# Downloading data for date 1997-05-03 00:00:00
# https://arthurhouhttps.pps.eosdis.nasa.gov/pub/gpmdata/1997/05/03/gis not available
# Downloading data for date 1997-05-04 00:00:00
# https://arthurhouhttps.pps.eosdis.nasa.gov/pub/gpmdata/1997/05/04/gis not available
# Downloading data for date 1997-05-05 00:00:00
# https://arthurhouhttps.pps.eosdis.nasa.gov/pub/gpmdata/1997/05/05/gis not available
# Downloading data for date 1997-05-06 00:00:00
# https://arthurhouhttps.pps.eosdis.nasa.gov/pub/gpmdata/1997/05/06/gis not available
# Downloading data for date 1997-05-07 00:00:00
# https://arthurhouhttps.pps.eosdis.nasa.gov/pub/gpmdata/1997/05/07/gis not available
# Downloading data for lusi1997 between 1997-10-09 00:00:00 and 1997-10-13 00:00:00
# Downloading data for date 1997-10-09 00:00:00
# https://arthurhouhttps.pps.eosdis.nasa.gov/pub/gpmdata/1997/10/09/gis not available
# Downloading data for date 1997-10-10 00:00:00
# https://arthurhouhttps.pps.eosdis.nasa.gov/pub/gpmdata/1997/10/10/gis not available
# Downloading data for date 1997-10-11 00:00:00
# https://arthurhouhttps.pps.eosdis.nasa.gov/pub/gpmdata/1997/10/11/gis not available
# Downloading data for date 1997-10-12 00:00:00
# https://arthurhouhttps.pps.eosdis.nasa.gov/pub/gpmdata/1997/10/12/gis not available
# Downloading data for date 1997-10-13 00:00:00
# https://arthurhouhttps.pps.eosdis.nasa.gov/pub/gpmdata/1997/10/13/gis not available
# Downloading data for susan1998 between 1998-01-05 00:00:00 and 1998-01-09 00:00:00
# Downloading data for date 1998-01-05 00:00:00
# https://arthurhouhttps.pps.eosdis.nasa.gov/pub/gpmdata/1998/01/05/gis not available
# Downloading data for date 1998-01-06 00:00:00
# https://arthurhouhttps.pps.eosdis.nasa.gov/pub/gpmdata/1998/01/06/gis not available
# Downloading data for date 1998-01-07 00:00:00
# https://arthurhouhttps.pps.eosdis.nasa.gov/pub/gpmdata/1998/01/07/gis not available
# Downloading data for date 1998-01-08 00:00:00
# https://arthurhouhttps.pps.eosdis.nasa.gov/pub/gpmdata/1998/01/08/gis not available
# Downloading data for date 1998-01-09 00:00:00
# https://arthurhouhttps.pps.eosdis.nasa.gov/pub/gpmdata/1998/01/09/gis not available
# Downloading data for dani1999 between 1999-01-19 00:00:00 and 1999-01-23 00:00:00
# Downloading data for date 1999-01-19 00:00:00
# https://arthurhouhttps.pps.eosdis.nasa.gov/pub/gpmdata/1999/01/19/gis not available
# Downloading data for date 1999-01-20 00:00:00
# https://arthurhouhttps.pps.eosdis.nasa.gov/pub/gpmdata/1999/01/20/gis not available
# Downloading data for date 1999-01-21 00:00:00
# https://arthurhouhttps.pps.eosdis.nasa.gov/pub/gpmdata/1999/01/21/gis not available
# Downloading data for date 1999-01-22 00:00:00
# https://arthurhouhttps.pps.eosdis.nasa.gov/pub/gpmdata/1999/01/22/gis not available
# Downloading data for date 1999-01-23 00:00:00
# https://arthurhouhttps.pps.eosdis.nasa.gov/pub/gpmdata/1999/01/23/gis not available
# Downloading data for neil2000 between 2000-04-11 00:00:00 and 2000-04-15 00:00:00
# Downloading data for date 2000-04-11 00:00:00
# https://arthurhouhttps.pps.eosdis.nasa.gov/pub/gpmdata/2000/04/11/gis not available
# Downloading data for date 2000-04-12 00:00:00
# https://arthurhouhttps.pps.eosdis.nasa.gov/pub/gpmdata/2000/04/12/gis not available
# Downloading data for date 2000-04-13 00:00:00
# https://arthurhouhttps.pps.eosdis.nasa.gov/pub/gpmdata/2000/04/13/gis not available
# Downloading data for date 2000-04-14 00:00:00
# https://arthurhouhttps.pps.eosdis.nasa.gov/pub/gpmdata/2000/04/14/gis not available
# Downloading data for date 2000-04-15 00:00:00
# https://arthurhouhttps.pps.eosdis.nasa.gov/pub/gpmdata/2000/04/15/gis not available
# Downloading data for paula2001 between 2001-02-28 00:00:00 and 2001-03-04 00:00:00
# Downloading data for date 2001-02-28 00:00:00
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[32], line 8
#       6     continue
#       7 print(f"Downloading data for {typhoon} between {start_date} and {end_date}")
# ----> 8 download_gpm_http(start_date=start_date,
#       9                   end_date=end_date,
#      10                   download_path=gpm_folder_path / typhoon / "GPM")
#
# Cell In[31], line 39, in download_gpm_http(start_date, end_date, download_path)
#      37     continue
#      38 file_list.append(file_path)
# ---> 39 r = requests.get(tiff_file, auth=(user_name, user_name))
#      40 print(r)
#      41 open(file_path, "wb").write(r.content)
#
# NameError: name 'user_name' is not defined
